# %% [markdown]
# ## Working on SVM

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
hr=pd.read_csv('C:/Users/Administrator/Desktop/Machine learning/with karthirmani/datasets/HR Analytics.csv')
hr=pd.get_dummies(hr)
hr.head()
# Out:
#    Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0   41          1       1102                 1          2              1
# 1   49          0        279                 8          1              1
# 2   37          1       1373                 2          2              1
# 3   33          0       1392                 3          4              1
# 4   27          0        591                 2          1              1
#
#    EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0               1                        2          94               3
# 1               2                        3          61               2
# 2               4                        4          92               2
# 3               5                        4          56               3
# 4               7                        1          40               3
#
#        ...       JobRole_Research Director  JobRole_Research Scientist  \
# ...

# %%
hr1=pd.DataFrame(preprocessing.StandardScaler().fit(hr).transform(hr))
hr1
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   """Entry point for launching an IPython kernel.
#             0         1         2         3         4    5         6   \
# 0     0.446350  2.280906  0.742527 -1.010909 -0.891688  0.0 -1.701283
# 1     1.322365 -0.438422 -1.297775 -0.147150 -1.868426  0.0 -1.699621
# 2     0.008343  2.280906  1.414363 -0.887515 -0.891688  0.0 -1.696298
# 3    -0.429664 -0.438422  1.461466 -0.764121  1.061787  0.0 -1.694636
# 4    -1.086676 -0.438422 -0.524295 -0.887515 -1.868426  0.0 -1.691313
# 5    -0.539166 -0.438422  0.502054 -0.887515 -0.891688  0.0 -1.689652
# ...

# %%
y=hr['Attrition']
xtrain,ytrain,xtest,ytest=train_test_split(hr1,y,test_size=0.3,random_state=100)

model=svm.SVC(gamma=0.001,C=100)
model.fit(xtrain,ytrain)
pred=model.predict(xtest)
print(confusion_matrix(ytest,pred,labels=[0,1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-976fac08ff59> in <module>
#       1 y=hr['Attrition']
# ----> 2 xtrain,ytrain,xtest,ytest=train_test_split(hr1,y,test_size=0.3,random_state=100)
#       3
#       4 model=svm.SVC(gamma=0.001,C=100)
#       5 model.fit(xtrain,ytrain)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2182         test_size = 0.25
#    2183
# -> 2184     arrays = indexable(*arrays)
#    2185
#    2186     if shuffle is False:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     258         else:
#     259             result.append(np.array(X))
# --> 260     check_consistent_length(*result)
#     261     return result
#     262
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
# ...

# %% [markdown]
# ## Working with Images

# %%
from sklearn.datasets import fetch_olivetti_faces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
data=pd.DataFrame(fetch_olivetti_faces()['data'])
print(data.shape)
print(np.sqrt(4096))
plt.imshow(np.array(data.iloc[0]).reshape(64,64))

plt.figure()
for i in range(10):
    image=plt.imshow(np.array(data.iloc[i]).reshape(64,64))
    ax=plt.subplot(2,5,i+1)
    ax.imshow(image,cmap='gray')
# Out:
# (400, 4096)
# 64.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-2432d99c7850> in <module>
#       9     image=plt.imshow(np.array(data.iloc[i]).reshape(64,64))
#      10     ax=plt.subplot(2,5,i+1)
# ---> 11     ax.imshow(image,cmap='gray')
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
# ...

# %% [markdown]
# ## using images

# %%
from sklearn.datasets import fetch_olivetti_faces
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
data = pd.DataFrame(fetch_olivetti_faces()['data'])
print(data.shape)
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(data)
data_scaled=pd.DataFrame(scaler.transform(data),columns=data.columns)
# Out:
# (400, 4096)
# C:\Users\Administrator\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype float32 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DataConversionWarning: Data with input dtype float32 were all converted to float64 by StandardScaler.
#   # This is added back by InteractiveShellApp.init_path()

# %%
data_scaled.shape
# Out:
# (400, 4096)

# %%
plt.imshow(np.array(data.iloc[0]).reshape(64,64),cmap = 'gray')
plt.figure(figsize=(10,12))
for i in range(100):
    image = np.array(data.iloc[i]).reshape(64,64)
    ax = plt.subplot(10,10, i+1)
    ax.imshow(image, cmap = 'gray')

# %%
evalues,evectors=np.linalg.eig(data.corr())

# %%
pca=PCA()
pca.fit(data)
df_pcs=pd.DataFrame(pca.components_)
df_pcs.shape
# Out:
# (400, 4096)

# %%
plt.figure(figsize=(10,12))
for i in range(100):
    image = np.array(df_pcs.iloc[i]).reshape(64,64)
    ax = plt.subplot(10,10, i+1)
    ax.imshow(image, cmap = 'gray')

# %%
pca.get_covariance().shape

# %%
df_pcs.loc[,51:4096]=0
image_rec
